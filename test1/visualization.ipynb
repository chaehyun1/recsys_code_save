# %% [markdown]
# ## clip similarity

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
# JSON 파일 경로
json_file = "../dataset/similarity_results.json"

# JSON 파일 로드
with open(json_file, "r", encoding="utf-8") as f:
    similarity_dict = json.load(f)

scores = list(similarity_dict.values())

# 히스토그램 시각화
plt.figure(figsize=(10, 5))
plt.hist(scores, bins=20, color='skyblue', edgecolor='black')
plt.title("Distribution of Similarity Scores (clip embedding)")
plt.xlabel("Similarity Score")
plt.ylabel("Frequency")
plt.xlim(0, 1)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
np.mean(list(similarity_dict.values()))
# Out:
# np.float64(0.3195110332686928)

# %%
# JSON 파일 경로
json_file = "../dataset/beauty_text_similarity.json"

# JSON 파일 로드
with open(json_file, "r", encoding="utf-8") as f:
    similarity_dict = json.load(f)

scores = list(similarity_dict.values())

# 히스토그램 시각화
plt.figure(figsize=(10, 5))
plt.hist(scores, bins=20, color='skyblue', edgecolor='black')
plt.title("Distribution of Similarity Scores (image caption vs. text)")
plt.xlabel("Similarity Score")
plt.ylabel("Frequency")
plt.xlim(0, 1)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
np.mean(list(similarity_dict.values()))
# Out:
# np.float64(0.48749693877551015)
